# %% [markdown]
# # Business Case:
# ### Can I predict BAMscore using NBA Combine Test Results? How can it to give insight to athletes + coaches?

# %% [markdown]
# ## (1) EDA + Cleaning BAM Data
# ### - Visualize the data
# ### - Make Observation/Hypothesis
# ### - Model data in modeling notebook

# %% [markdown]
# ### Target Audience = High School Basketball Athletes that are trying to plan and play at next level

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as scs
import seaborn as sns
import os
import plotly.express as px
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import maxabs_scale
from sklearn.pipeline import Pipeline

# %%
## Name the dataset "df"
df = pd.read_excel('bam_data.xlsx')

# %%
df.info()
# See if anything is funky with the data using .info() and the eye test
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1059 entries, 0 to 1058
# Data columns (total 16 columns):
# BAMid                 1057 non-null object
# Approach Vertical     986 non-null float64
# Vertical Jump         1019 non-null float64
# 3/4 Court sprint      1026 non-null object
# 4-Way agility         1020 non-null object
# Reaction Shuttle      1024 non-null float64
# BAMScore              1056 non-null float64
# Wingspan              1012 non-null float64
# Reach                 1012 non-null float64
# Height                1012 non-null float64
# Weight                1012 non-null float64
# Body Comp             1012 non-null float64
# Hand Length           1010 non-null float64
# Hand Width            1009 non-null float64
# Unnamed: 14           0 non-null float64
# Unnamed: 15           1 non-null object
# dtypes: float64(12), object(4)
# memory usage: 132.5+ KB

# %%
df
# Out:
#      BAMid  Approach Vertical  Vertical Jump 3/4 Court sprint   4-Way agility  \
# 0     1037               33.5           28.5              3.376        11.471
# 1      656               30.5           21.5              3.486        12.114
# 2      477               37.0           31.0               3.23        12.036
# 3     1200               29.0           23.0               3.37        12.509
# 4     1501               31.0           26.0              3.389        12.724
# ...    ...                ...            ...                ...           ...
# 1054   574               36.0           31.0              3.424        12.654
# 1055   651               31.5           26.5              3.256        11.136
# 1056   NaN                NaN            NaN                NaN           NaN
# 1057                      NaN            NaN                NaN           NaN
# 1058   NaN                NaN            NaN                NaN           NaN
#
#       Reaction Shuttle  BAMScore  Wingspan  Reach  Height  Weight  Body Comp  \
# 0                3.669    2003.0     72.75   94.0   70.00   174.4        9.8
# 1                3.355    1865.0     82.00  104.5   79.50   188.4       21.9
# 2                3.562    2005.0     81.50   99.0   74.00   196.5       13.9
# 3                3.173    1902.0     79.50  101.0   77.50   205.0       10.6
# 4                3.316    1903.0     77.00  101.5   78.00   180.0       15.4
# ...                ...       ...       ...    ...     ...     ...        ...
# 1054             3.635    1917.0     72.00   88.0   68.25   147.4        7.9
# 1055             3.343    2029.0     74.00   91.5   68.00   172.1       23.4
# 1056               NaN       NaN       NaN    NaN     NaN     NaN        NaN
# 1057               NaN       NaN       NaN    NaN     NaN     NaN        NaN
# 1058               NaN       NaN       NaN    NaN     NaN     NaN        NaN
#
#       Hand Length  Hand Width  Unnamed: 14 Unnamed: 15
# 0            7.50        8.25          NaN         NaN
# 1            7.50        8.75          NaN         NaN
# 2            9.00        9.50          NaN         NaN
# 3            8.25        9.25          NaN         NaN
# 4            8.00       10.00          NaN         NaN
# ...           ...         ...          ...         ...
# 1054         8.00        8.50          NaN         NaN
# 1055         7.00        8.50          NaN         NaN
# 1056          NaN         NaN          NaN         NaN
# 1057          NaN         NaN          NaN         NaN
# 1058          NaN         NaN          NaN
#
# [1059 rows x 16 columns]

# %%
# This shows me around 1000 values ... what this shows me

# %%
# I dont like the looks of Unnamed 14 + 15. Reshape my coding grammer so I can tidy up the data 
df.columns = [column.strip().lower().replace(" ", "_") for column in df.columns]
df.head()
# Out:
#   bamid  approach_vertical  vertical_jump 3/4_court_sprint 4-way_agility  \
# 0  1037               33.5           28.5            3.376        11.471
# 1   656               30.5           21.5            3.486        12.114
# 2   477               37.0           31.0             3.23        12.036
# 3  1200               29.0           23.0             3.37        12.509
# 4  1501               31.0           26.0            3.389        12.724
#
#    reaction_shuttle  bamscore  wingspan  reach  height  weight  body_comp  \
# 0             3.669    2003.0     72.75   94.0    70.0   174.4        9.8
# 1             3.355    1865.0     82.00  104.5    79.5   188.4       21.9
# 2             3.562    2005.0     81.50   99.0    74.0   196.5       13.9
# 3             3.173    1902.0     79.50  101.0    77.5   205.0       10.6
# 4             3.316    1903.0     77.00  101.5    78.0   180.0       15.4
#
#    hand_length  hand_width  unnamed:_14 unnamed:_15
# 0         7.50        8.25          NaN         NaN
# 1         7.50        8.75          NaN         NaN
# 2         9.00        9.50          NaN         NaN
# 3         8.25        9.25          NaN         NaN
# 4         8.00       10.00          NaN         NaN

# %%
column_names = ['bamid', '3/4_court_sprint', '4-way_agility', 'unnamed:_14', 'unnamed:_15']

for column in df.columns:
    if column in column_names:
        df[column].replace('', 0)
        df[column] = pd.to_numeric(df[column], errors='coerce')
    df[column].fillna(df[column].mean(), inplace=True)
    print(f'{column}: fixed!')
# Have to change spaces (strings) to numberic values to we can work with it
# Out:
# bamid: fixed!
# approach_vertical: fixed!
# vertical_jump: fixed!
# 3/4_court_sprint: fixed!
# 4-way_agility: fixed!
# reaction_shuttle: fixed!
# bamscore: fixed!
# wingspan: fixed!
# reach: fixed!
# height: fixed!
# weight: fixed!
# body_comp: fixed!
# hand_length: fixed!
# hand_width: fixed!
# unnamed:_14: fixed!
# unnamed:_15: fixed!

# %%
df.columns
# Out:
# Index(['bamid', 'approach_vertical', 'vertical_jump', '3/4_court_sprint',
#        '4-way_agility', 'reaction_shuttle', 'bamscore', 'wingspan', 'reach',
#        'height', 'weight', 'body_comp', 'hand_length', 'hand_width',
#        'unnamed:_14', 'unnamed:_15'],
#       dtype='object')

# %%
# rename columns so they all work later on in notebook
df.rename(columns = {'3/4_court_sprint':'three_quarter_court_sprint', '4-way_agility':'four_way_agility'}, inplace = True)

# %%
df
# Out:
#             bamid  approach_vertical  vertical_jump  \
# 0     1037.000000          33.500000      28.500000
# 1      656.000000          30.500000      21.500000
# 2      477.000000          37.000000      31.000000
# 3     1200.000000          29.000000      23.000000
# 4     1501.000000          31.000000      26.000000
# ...           ...                ...            ...
# 1054   574.000000          36.000000      31.000000
# 1055   651.000000          31.500000      26.500000
# 1056   858.025568          31.829615      25.860157
# 1057   858.025568          31.829615      25.860157
# 1058   858.025568          31.829615      25.860157
#
#       three_quarter_court_sprint  four_way_agility  reaction_shuttle  \
# 0                       3.376000         11.471000          3.669000
# 1                       3.486000         12.114000          3.355000
# 2                       3.230000         12.036000          3.562000
# 3                       3.370000         12.509000          3.173000
# 4                       3.389000         12.724000          3.316000
# ...                          ...               ...               ...
# 1054                    3.424000         12.654000          3.635000
# 1055                    3.256000         11.136000          3.343000
# 1056                    3.467047         12.247189          3.505243
# 1057                    3.467047         12.247189          3.505243
# 1058                    3.467047         12.247189          3.505243
#
#          bamscore   wingspan      reach     height     weight  body_comp  \
# 0     2003.000000  72.750000   94.00000  70.000000  174.40000   9.800000
# 1     1865.000000  82.000000  104.50000  79.500000  188.40000  21.900000
# 2     2005.000000  81.500000   99.00000  74.000000  196.50000  13.900000
# 3     1902.000000  79.500000  101.00000  77.500000  205.00000  10.600000
# 4     1903.000000  77.000000  101.50000  78.000000  180.00000  15.400000
# ...           ...        ...        ...        ...        ...        ...
# 1054  1917.000000  72.000000   88.00000  68.250000  147.40000   7.900000
# 1055  2029.000000  74.000000   91.50000  68.000000  172.10000  23.400000
# 1056  1890.976326  78.089797   98.71418  75.094195  180.73582  14.979496
# 1057  1890.976326  78.089797   98.71418  75.094195  180.73582  14.979496
# 1058  1890.976326  78.089797   98.71418  75.094195  180.73582  14.979496
#
#       hand_length  hand_width  unnamed:_14  unnamed:_15
# 0        7.500000    8.250000          NaN          NaN
# 1        7.500000    8.750000          NaN          NaN
# 2        9.000000    9.500000          NaN          NaN
# 3        8.250000    9.250000          NaN          NaN
# 4        8.000000   10.000000          NaN          NaN
# ...           ...         ...          ...          ...
# 1054     8.000000    8.500000          NaN          NaN
# 1055     7.000000    8.500000          NaN          NaN
# 1056     8.049381    8.876189          NaN          NaN
# 1057     8.049381    8.876189          NaN          NaN
# 1058     8.049381    8.876189          NaN          NaN
#
# [1059 rows x 16 columns]

# %%
df.drop(columns=['unnamed:_14','unnamed:_15','bamid'],inplace=True)
# Remove because only 1 value from our df.info check above

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1059 entries, 0 to 1058
# Data columns (total 13 columns):
# approach_vertical             1059 non-null float64
# vertical_jump                 1059 non-null float64
# three_quarter_court_sprint    1059 non-null float64
# four_way_agility              1059 non-null float64
# reaction_shuttle              1059 non-null float64
# bamscore                      1059 non-null float64
# wingspan                      1059 non-null float64
# reach                         1059 non-null float64
# height                        1059 non-null float64
# weight                        1059 non-null float64
# body_comp                     1059 non-null float64
# hand_length                   1059 non-null float64
# hand_width                    1059 non-null float64
# dtypes: float64(13)
# memory usage: 107.7 KB

# %%
df.columns.isna()
# Check and make sure nulls are gone - looking for all false.
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False])

# %% [markdown]
# ## EDA

# %%
# What's BAMscore even look like? Lets find out - more values?

# %%
# First lets use the eye test and look at relationships in our data + identify multicollinearity.
sns.pairplot(df)
# top right column where points look like they are lining up - this means it could be a categorical variable
# We can use bins on this in later analysis
# Diaganols shows us baseline normal distribution
# Can see on reaction shuttle and 3/4 court sprint outlier because it's skewed to left

# %%
df['bamscore'].plot('hist')
# Out:
# /Users/bryanjamieson/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning:
#
# `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='hist')` instead of `Series.plot('hist',)`.

# %%
df['bamscore'].describe(),
# Out:
# (count    1059.000000
#  mean     1890.976326
#  std       134.866028
#  min      1343.000000
#  25%      1811.000000
#  50%      1899.000000
#  75%      1981.000000
#  max      2298.000000
#  Name: bamscore, dtype: float64,)

# %%
bam_mu = df['bamscore'].mean()
bam_std = df['bamscore'].std()

min95 = bam_mu-2*bam_std
max95 = bam_mu+2*bam_std


def get_rank_bam_score(bam):
    if bam > bam_mu+1*bam_std:
        return 5
    if bam > bam_mu:
        return 4
    if bam > bam_mu - bam_std:
        return 3
    if bam > bam_mu - 2*bam_std:
        return 2
    return 1

# %%
df['bam_score_rank'] = df['bamscore'].apply(get_rank_bam_score)
df.head()
# Out:
#    approach_vertical  vertical_jump  three_quarter_court_sprint  \
# 0               33.5           28.5                       3.376
# 1               30.5           21.5                       3.486
# 2               37.0           31.0                       3.230
# 3               29.0           23.0                       3.370
# 4               31.0           26.0                       3.389
#
#    four_way_agility  reaction_shuttle  bamscore  wingspan  reach  height  \
# 0            11.471             3.669    2003.0     72.75   94.0    70.0
# 1            12.114             3.355    1865.0     82.00  104.5    79.5
# 2            12.036             3.562    2005.0     81.50   99.0    74.0
# 3            12.509             3.173    1902.0     79.50  101.0    77.5
# 4            12.724             3.316    1903.0     77.00  101.5    78.0
#
#    weight  body_comp  hand_length  hand_width  bam_score_rank
# 0   174.4        9.8         7.50        8.25               4
# 1   188.4       21.9         7.50        8.75               3
# 2   196.5       13.9         9.00        9.50               4
# 3   205.0       10.6         8.25        9.25               4
# 4   180.0       15.4         8.00       10.00               4

# %%
av_rank_bam_score = pd.value_counts(df['bam_score_rank'].values, sort=False)
av_rank_bam_score.plot.barh()

# %% [markdown]
# ### BAMscore Range: [1343-2298]
# ### BAMscore Min: [1343]
# ### BAMscore Max: [2298]

# %%
# Want to look at bam scores relationship to the factors
# I love violin plots because it's easy to see the data

# %% [markdown]
# ## Observations:
# ### fig3 - 3/4 court sprint has outlier
# ### fig4 - 4-way-agility outlier
# ### fig10 - body_comp - has outlier and 0 values

# %%
# redo this using axes example
## https://python.astrotech.io/matplotlib/multiple-figures.html
## https://matplotlib.org/stable/gallery/lines_bars_and_markers/simple_plot.html
# save image

# %%
# I noticed weight and body comp had at least 1 value of 0. So I want to locate these and fix them (replace mean)
# Will do this after split

# %%
#Want to look at those 3 again

# %%
hist3 = df['three_quarter_court_sprint'].plot('hist')
# outliers
# Out:
# /Users/bryanjamieson/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning:
#
# `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='hist')` instead of `Series.plot('hist',)`.

# %%
hist4 = df['four_way_agility'].plot('hist')
# more normal
# Out:
# /Users/bryanjamieson/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning:
#
# `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='hist')` instead of `Series.plot('hist',)`.

# %%
hist10 = df['body_comp'].plot('hist')
# more normal
# Out:
# /Users/bryanjamieson/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning:
#
# `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='hist')` instead of `Series.plot('hist',)`.

# %%
df.describe()
# Out:
#        approach_vertical  vertical_jump  three_quarter_court_sprint  \
# count        1059.000000    1059.000000                 1059.000000
# mean           31.829615      25.860157                    3.467047
# std             3.423395       3.065653                    0.335502
# min            19.000000      14.000000                    2.950000
# 25%            30.000000      24.000000                    3.339500
# 50%            31.829615      25.860157                    3.424000
# 75%            34.000000      28.000000                    3.537500
# max            43.500000      38.000000                    9.954000
#
#        four_way_agility  reaction_shuttle     bamscore     wingspan  \
# count       1059.000000       1059.000000  1059.000000  1059.000000
# mean          12.247189          3.505243  1890.976326    78.089797
# std            0.652726          0.273783   134.866028     5.143227
# min           10.359000          2.914000  1343.000000    27.000000
# 25%           11.806000          3.348000  1811.000000    75.500000
# 50%           12.244000          3.492000  1899.000000    78.000000
# 75%           12.658000          3.634000  1981.000000    80.500000
# max           14.775000          6.759000  2298.000000   150.000000
#
#              reach       height       weight    body_comp  hand_length  \
# count  1059.000000  1059.000000  1059.000000  1059.000000  1059.000000
# mean     98.714180    75.094195   180.735820    14.979496     8.049381
# std       5.824608     5.128197    28.002496     6.052069     0.533210
# min       7.500000    37.875000     0.000000     0.000000     4.250000
# 25%      96.000000    72.750000   165.200000    10.400000     7.750000
# 50%      98.714180    75.000000   179.500000    14.979496     8.000000
# 75%     102.000000    77.250000   195.000000    18.900000     8.500000
# max     115.000000   190.700000   303.400000    34.500000     9.750000
#
#         hand_width  bam_score_rank
# count  1059.000000     1059.000000
# mean      8.876189        3.483475
# std       0.638452        0.982099
# min       4.500000        1.000000
# 25%       8.500000        3.000000
# 50%       8.876189        4.000000
# 75%       9.250000        4.000000
# max      11.000000        5.000000

# %%
# df.loc[(df.weight == 0)]
# to use in modeling notebook

# %%
# df.loc[(df.body_comp == 0)]
# to use in modeling notebook

# %%
# Replace these with mean now
df.mean()
# Out:
# approach_vertical               31.829615
# vertical_jump                   25.860157
# three_quarter_court_sprint       3.467047
# four_way_agility                12.247189
# reaction_shuttle                 3.505243
# bamscore                      1890.976326
# wingspan                        78.089797
# reach                           98.714180
# height                          75.094195
# weight                         180.735820
# body_comp                       14.979496
# hand_length                      8.049381
# hand_width                       8.876189
# bam_score_rank                   3.483475
# dtype: float64

# %%
df
# Fix 0 outliers
# Out:
#       approach_vertical  vertical_jump  three_quarter_court_sprint  \
# 0             33.500000      28.500000                    3.376000
# 1             30.500000      21.500000                    3.486000
# 2             37.000000      31.000000                    3.230000
# 3             29.000000      23.000000                    3.370000
# 4             31.000000      26.000000                    3.389000
# ...                 ...            ...                         ...
# 1054          36.000000      31.000000                    3.424000
# 1055          31.500000      26.500000                    3.256000
# 1056          31.829615      25.860157                    3.467047
# 1057          31.829615      25.860157                    3.467047
# 1058          31.829615      25.860157                    3.467047
#
#       four_way_agility  reaction_shuttle     bamscore   wingspan      reach  \
# 0            11.471000          3.669000  2003.000000  72.750000   94.00000
# 1            12.114000          3.355000  1865.000000  82.000000  104.50000
# 2            12.036000          3.562000  2005.000000  81.500000   99.00000
# 3            12.509000          3.173000  1902.000000  79.500000  101.00000
# 4            12.724000          3.316000  1903.000000  77.000000  101.50000
# ...                ...               ...          ...        ...        ...
# 1054         12.654000          3.635000  1917.000000  72.000000   88.00000
# 1055         11.136000          3.343000  2029.000000  74.000000   91.50000
# 1056         12.247189          3.505243  1890.976326  78.089797   98.71418
# 1057         12.247189          3.505243  1890.976326  78.089797   98.71418
# 1058         12.247189          3.505243  1890.976326  78.089797   98.71418
#
#          height     weight  body_comp  hand_length  hand_width  bam_score_rank
# 0     70.000000  174.40000   9.800000     7.500000    8.250000               4
# 1     79.500000  188.40000  21.900000     7.500000    8.750000               3
# 2     74.000000  196.50000  13.900000     9.000000    9.500000               4
# 3     77.500000  205.00000  10.600000     8.250000    9.250000               4
# 4     78.000000  180.00000  15.400000     8.000000   10.000000               4
# ...         ...        ...        ...          ...         ...             ...
# 1054  68.250000  147.40000   7.900000     8.000000    8.500000               4
# 1055  68.000000  172.10000  23.400000     7.000000    8.500000               5
# 1056  75.094195  180.73582  14.979496     8.049381    8.876189               3
# 1057  75.094195  180.73582  14.979496     8.049381    8.876189               3
# 1058  75.094195  180.73582  14.979496     8.049381    8.876189               3
#
# [1059 rows x 14 columns]

# %%
df['body_comp'].replace(to_replace=0, value = df['body_comp'].mean(), inplace = True)

# %%
df['weight'].replace(to_replace=0, value = df['weight'].mean(), inplace = True)

# %%
df.drop(columns=['bam_score_rank'],inplace=True)

# %% [markdown]
# ## Now we need to take care of outliers

# %%
df.describe()
# Out:
#        approach_vertical  vertical_jump  three_quarter_court_sprint  \
# count        1059.000000    1059.000000                 1059.000000
# mean           31.829615      25.860157                    3.467047
# std             3.423395       3.065653                    0.335502
# min            19.000000      14.000000                    2.950000
# 25%            30.000000      24.000000                    3.339500
# 50%            31.829615      25.860157                    3.424000
# 75%            34.000000      28.000000                    3.537500
# max            43.500000      38.000000                    9.954000
#
#        four_way_agility  reaction_shuttle     bamscore     wingspan  \
# count       1059.000000       1059.000000  1059.000000  1059.000000
# mean          12.247189          3.505243  1890.976326    78.089797
# std            0.652726          0.273783   134.866028     5.143227
# min           10.359000          2.914000  1343.000000    27.000000
# 25%           11.806000          3.348000  1811.000000    75.500000
# 50%           12.244000          3.492000  1899.000000    78.000000
# 75%           12.658000          3.634000  1981.000000    80.500000
# max           14.775000          6.759000  2298.000000   150.000000
#
#              reach       height       weight    body_comp  hand_length  \
# count  1059.000000  1059.000000  1059.000000  1059.000000  1059.000000
# mean     98.714180    75.094195   181.077153    15.007786     8.049381
# std       5.824608     5.128197    26.875151     6.016857     0.533210
# min       7.500000    37.875000    10.300000     4.000000     4.250000
# 25%      96.000000    72.750000   165.250000    10.400000     7.750000
# 50%      98.714180    75.000000   179.600000    14.979496     8.000000
# 75%     102.000000    77.250000   195.000000    18.900000     8.500000
# max     115.000000   190.700000   303.400000    34.500000     9.750000
#
#         hand_width
# count  1059.000000
# mean      8.876189
# std       0.638452
# min       4.500000
# 25%       8.500000
# 50%       8.876189
# 75%       9.250000
# max      11.000000

# %%
# Add classifications to test set
# before classifier, drop bamscore from dataset, bamscorerank becomes target

# continuous - df.bamscore
# classifier - df.bamrank
# when I choose one, I have to drop from dataset

# %% [markdown]
# ## Observation and hypothesis

# %%
# Want to clean 0 values in data so outliers are taken out and will do this after I split data
# Outliers are present. 3/4 court sprint apparent
# Hypothesis is the combine tests are more important than body measurements, need to focus on those

# %%
df.describe()
# Out:
#        approach_vertical  vertical_jump  three_quarter_court_sprint  \
# count        1059.000000    1059.000000                 1059.000000
# mean           31.829615      25.860157                    3.467047
# std             3.423395       3.065653                    0.335502
# min            19.000000      14.000000                    2.950000
# 25%            30.000000      24.000000                    3.339500
# 50%            31.829615      25.860157                    3.424000
# 75%            34.000000      28.000000                    3.537500
# max            43.500000      38.000000                    9.954000
#
#        four_way_agility  reaction_shuttle     bamscore     wingspan  \
# count       1059.000000       1059.000000  1059.000000  1059.000000
# mean          12.247189          3.505243  1890.976326    78.089797
# std            0.652726          0.273783   134.866028     5.143227
# min           10.359000          2.914000  1343.000000    27.000000
# 25%           11.806000          3.348000  1811.000000    75.500000
# 50%           12.244000          3.492000  1899.000000    78.000000
# 75%           12.658000          3.634000  1981.000000    80.500000
# max           14.775000          6.759000  2298.000000   150.000000
#
#              reach       height       weight    body_comp  hand_length  \
# count  1059.000000  1059.000000  1059.000000  1059.000000  1059.000000
# mean     98.714180    75.094195   181.077153    15.007786     8.049381
# std       5.824608     5.128197    26.875151     6.016857     0.533210
# min       7.500000    37.875000    10.300000     4.000000     4.250000
# 25%      96.000000    72.750000   165.250000    10.400000     7.750000
# 50%      98.714180    75.000000   179.600000    14.979496     8.000000
# 75%     102.000000    77.250000   195.000000    18.900000     8.500000
# max     115.000000   190.700000   303.400000    34.500000     9.750000
#
#         hand_width
# count  1059.000000
# mean      8.876189
# std       0.638452
# min       4.500000
# 25%       8.500000
# 50%       8.876189
# 75%       9.250000
# max      11.000000

# %%
df.to_csv('bam_data.csv',index = None)

# %%
# Index = None - do this to not have blank index/unamed column
